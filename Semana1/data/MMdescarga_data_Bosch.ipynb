# %% [markdown]
# # **Descarga de datos de la competición por medio de código**

# %% [markdown]
# Los datos se pueden descargar directamente de:
# https://www.kaggle.com/c/bosch-production-line-performance/data

# %%
# Montar el drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Moverse a la carpeta donde descargar los datos (en esta carpeta deben esta su "API Key" de Kaggle)
import os 
os.environ["KAGGLE_CONFIG_DIR"] = "/content/drive/My Drive/Kaggle"
# %cd /content/drive/MyDrive/Kaggle/

# %% [markdown]
# Mas información de como obtner credenciales de Kaggle en el siguiente link https://github.com/Kaggle/kaggle-api

# %%
# !pip install kaggle

# %%
# Descargar los datos desde la API de Kaggle
# Descargamos "test_numeric.csv.zip"

# !kaggle competitions download -c bosch-production-line-performance -f test_numeric.csv.zip

# %%
# Descargamos "test_categorical.csv.zip"
# !kaggle competitions download -c bosch-production-line-performance -f test_categorical.csv.zip

# %%
# Verificar que se tienen los datos
# %ls

# %% [markdown]
# # **Muy importante: Los datos se guardaran en "/content/drive/My Drive/Kaggle"**
